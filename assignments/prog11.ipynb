# %% [markdown]
# # Programming assignment 11

# %% [markdown]
# ## Global surface temperature statistics
#
# This task analyzes the [NASA GISS Global Surface Temperature Analysis (GISTEMP v4)](https://data.giss.nasa.gov/gistemp/), one of the most widely used datasets of historical surface temperature change. The dataset reports temperature anomalies relative to the mean annual cycle (climatology) of 1951-1980. It covers the period 1880 through present with monthly time resolution and 2°x2° spatial resolution.
#
# For this task, the data have been averaged globally and annually, giving the global mean temperature anomaly (relative to 1951-1980) for each year. The data are in `prog11_files/gistemp_globalmean.nc`. (Original GISTEMP data, which you do not need for this task are available via OPeNDAP from [NOAA PSL.]('http://www.psl.noaa.gov/thredds/dodsC/Datasets/gistemp/combined/1200km/air.2x2.1200.mon.anom.comb.nc'))
#
# ### Compare decades
#
# Compare the global mean surface temperature for the 2010s (2010-2019) to the 1990s. Report the mean, standard deviation, and standard error of the mean for each decade. Report the difference in mean between decades and p-value for the difference. Report the 95% confidence interval for the difference in means. Report results with 3 significant digits (to assist with grading), even though 2 significant digits is the precision of this data.
# Neglect serial correlation of the annual means.
# The xarray std() method and numpy.std() both divide by N (number of elements) in their calculations (i.e. population standard deviation). To obtain the sample standard deviation, which is what we want for  use `ddof=1` keyword (delta degrees of freedom).
#
# (Here are some numbers that you can use to check your work. You don't need to turn in any of these calculations. The global mean temperature anomaly for the 2000s decade was 0.594 °C ± 0.089 (std) ± 0.028 (sem). The change in mean temperature from the 2000s to 2010s was +0.217 with a 95% confidence interval [0.104, 0.330]. These temperature changes are very unlikely under the null hypothesis of a common mean (p=0.00078, two-sided t test).)

# %%
# Write your code here

# %% [markdown]
# *Write your AI statement here*

# %% [markdown]
# ### Fit trends
#
# Fit a linear trend to the entire time range (1880-present) and 30-year intervals 1900-1930, 1930-1960, 1960-1990, 1990-2020. Report the linear trend (slope) and p-value for the slope for each of these time ranges.
#
# ![gistemp.png](attachment:a24f1c55-cd49-4ea2-a8fb-c74c8e362121.png)

# %%
# Write your code here

# %% [markdown]
# *Write your AI statement here*
